# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime
import os

# %%
#create set of random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

#add the lat and lng to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each lat and lng combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If city is unique add to cities list
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 802

# %%
#starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval")
print('-------------------------')

#Create counters
record_count = 1
set_count = 1

#loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    #add 1 to record count
    record_count += 1

# Run API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
    
        #Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
#If an error occurs, skip the city
    except:
        print("City not found, Skipping...")
        pass

#Indicate the Data loading is complete
print("----------------------------")
print("Date Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | mrirt
# City not found, Skipping...
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | chumikan
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | srednekolymsk
# Processing Record 10 of Set 1 | grindavik
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | grand gaube
# Processing Record 13 of Set 1 | borogontsy
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | artur nogueira
# Processing Record 16 of Set 1 | cherskiy
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | montenegro
# Processing Record 19 of Set 1 | padang
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | esperance
# Processing Record 22 of Set 1 | barentsburg
# City not found, Skipping...
# Processing Record 23 of Set 1 | tolbazy
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | baykalsk
# Processing Record 28 of Set 1 | ndele
# Processing Record 29 of Set 1 | santo antonio do taua
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | karkaralinsk
# City not found, Skipping...
# Processing Record 33 of Set 1 | izsak
# Processing Record 34 of Set 1 | fortuna
# Processing Record 35 of Set 1 | naze
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | bac lieu
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | high prairie
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | tuy hoa
# Processing Record 43 of Set 1 | mashhad
# Processing Record 44 of Set 1 | rawson
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found, Skipping...
# Processing Record 46 of Set 1 | ouango
# Processing Record 47 of Set 1 | jiuquan
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found, Skipping...
# Processing Record 49 of Set 1 | amderma
# City not found, Skipping...
# Processing Record 50 of Set 1 | saleaula
# City not found, Skipping...
# Processing Record 1 of Set 2 | lerwick
# Processing Record 2 of Set 2 | komsomolskiy
# Processing Record 3 of Set 2 | ahumada
# City not found, Skipping...
# Processing Record 4 of Set 2 | tourlaville
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | darhan
# Processing Record 7 of Set 2 | anori
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | klaksvik
# Processing Record 10 of Set 2 | bridlington
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | port macquarie
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | daru
# Processing Record 16 of Set 2 | asau
# Processing Record 17 of Set 2 | saint-denis
# Processing Record 18 of Set 2 | taltal
# Processing Record 19 of Set 2 | vostok
# Processing Record 20 of Set 2 | ixtapa
# Processing Record 21 of Set 2 | mvuma
# Processing Record 22 of Set 2 | palabuhanratu
# City not found, Skipping...
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | nieuwpoort
# Processing Record 25 of Set 2 | pafos
# Processing Record 26 of Set 2 | port blair
# Processing Record 27 of Set 2 | itarema
# Processing Record 28 of Set 2 | yafran
# Processing Record 29 of Set 2 | oulainen
# Processing Record 30 of Set 2 | saint-augustin
# Processing Record 31 of Set 2 | santa maria
# Processing Record 32 of Set 2 | ulladulla
# Processing Record 33 of Set 2 | hurghada
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | ahipara
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | luau
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | saquarema
# Processing Record 41 of Set 2 | kollumerland
# City not found, Skipping...
# Processing Record 42 of Set 2 | olafsvik
# Processing Record 43 of Set 2 | namatanai
# Processing Record 44 of Set 2 | geraldton
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | eydhafushi
# Processing Record 48 of Set 2 | eureka
# Processing Record 49 of Set 2 | rupert
# Processing Record 50 of Set 2 | bontang
# Processing Record 1 of Set 3 | guacimo
# Processing Record 2 of Set 3 | oxelosund
# Processing Record 3 of Set 3 | hualmay
# Processing Record 4 of Set 3 | russell
# Processing Record 5 of Set 3 | port hedland
# Processing Record 6 of Set 3 | witu
# Processing Record 7 of Set 3 | cortez
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | khandyga
# Processing Record 10 of Set 3 | belyy yar
# Processing Record 11 of Set 3 | mungwi
# Processing Record 12 of Set 3 | chagda
# City not found, Skipping...
# Processing Record 13 of Set 3 | attawapiskat
# City not found, Skipping...
# Processing Record 14 of Set 3 | palakkad
# Processing Record 15 of Set 3 | masjed-e soleyman
# City not found, Skipping...
# Processing Record 16 of Set 3 | glencoe
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | areia branca
# Processing Record 19 of Set 3 | lakhisarai
# Processing Record 20 of Set 3 | balykshi
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | miles city
# Processing Record 23 of Set 3 | toda raisingh
# Processing Record 24 of Set 3 | daniel flores
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | lavaltrie
# Processing Record 28 of Set 3 | kyle
# Processing Record 29 of Set 3 | razgrad
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | axim
# Processing Record 32 of Set 3 | korla
# Processing Record 33 of Set 3 | sinjai
# Processing Record 34 of Set 3 | narsaq
# Processing Record 35 of Set 3 | yaizu
# Processing Record 36 of Set 3 | san ramon
# Processing Record 37 of Set 3 | boras
# Processing Record 38 of Set 3 | singaparna
# Processing Record 39 of Set 3 | laguna
# Processing Record 40 of Set 3 | muros
# Processing Record 41 of Set 3 | sindor
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | bubaque
# Processing Record 45 of Set 3 | concordia
# Processing Record 46 of Set 3 | isangel
# Processing Record 47 of Set 3 | new norfolk
# Processing Record 48 of Set 3 | mayo
# Processing Record 49 of Set 3 | maningrida
# Processing Record 50 of Set 3 | saint-prosper
# Processing Record 1 of Set 4 | raga
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | muli
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | kalmunai
# Processing Record 6 of Set 4 | vinh
# Processing Record 7 of Set 4 | sechura
# Processing Record 8 of Set 4 | karpogory
# Processing Record 9 of Set 4 | inhambane
# Processing Record 10 of Set 4 | dingle
# Processing Record 11 of Set 4 | mocuba
# Processing Record 12 of Set 4 | nampa
# Processing Record 13 of Set 4 | roma
# Processing Record 14 of Set 4 | portland
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | bestobe
# Processing Record 17 of Set 4 | takoradi
# Processing Record 18 of Set 4 | pevek
# Processing Record 19 of Set 4 | acapulco
# Processing Record 20 of Set 4 | ravar
# Processing Record 21 of Set 4 | sao filipe
# Processing Record 22 of Set 4 | itaquyry
# Processing Record 23 of Set 4 | coihaique
# Processing Record 24 of Set 4 | phonhong
# Processing Record 25 of Set 4 | san carlos
# Processing Record 26 of Set 4 | krasnoselkup
# Processing Record 27 of Set 4 | bamiantong
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | namanga
# Processing Record 30 of Set 4 | sinnamary
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | gasa
# Processing Record 33 of Set 4 | ternate
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | aklavik
# Processing Record 36 of Set 4 | enterprise
# Processing Record 37 of Set 4 | sevierville
# Processing Record 38 of Set 4 | port alfred
# Processing Record 39 of Set 4 | tautira
# Processing Record 40 of Set 4 | presidente medici
# Processing Record 41 of Set 4 | tombouctou
# Processing Record 42 of Set 4 | beringovskiy
# Processing Record 43 of Set 4 | turukhansk
# Processing Record 44 of Set 4 | oranjemund
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | clyde river
# Processing Record 47 of Set 4 | pisco
# Processing Record 48 of Set 4 | vila do maio
# Processing Record 49 of Set 4 | bambous virieux
# Processing Record 50 of Set 4 | cidreira
# Processing Record 1 of Set 5 | huarmey
# Processing Record 2 of Set 5 | bogalusa
# Processing Record 3 of Set 5 | luoyang
# Processing Record 4 of Set 5 | bonavista
# Processing Record 5 of Set 5 | la romana
# Processing Record 6 of Set 5 | manaure
# Processing Record 7 of Set 5 | nouadhibou
# Processing Record 8 of Set 5 | quang ngai
# Processing Record 9 of Set 5 | shirokiy
# Processing Record 10 of Set 5 | dikson
# Processing Record 11 of Set 5 | saint-pierre
# Processing Record 12 of Set 5 | ribeira grande
# Processing Record 13 of Set 5 | golspie
# Processing Record 14 of Set 5 | busayra
# Processing Record 15 of Set 5 | qasigiannguit
# Processing Record 16 of Set 5 | nanma
# Processing Record 17 of Set 5 | lyubech
# Processing Record 18 of Set 5 | khatanga
# Processing Record 19 of Set 5 | manzhouli
# Processing Record 20 of Set 5 | kungurtug
# Processing Record 21 of Set 5 | mount gambier
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | belushya guba
# City not found, Skipping...
# Processing Record 24 of Set 5 | santa cruz del sur
# Processing Record 25 of Set 5 | bethel
# Processing Record 26 of Set 5 | hilo
# Processing Record 27 of Set 5 | jussara
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | sendafa
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | conakry
# Processing Record 32 of Set 5 | vaitupu
# City not found, Skipping...
# Processing Record 33 of Set 5 | ludvika
# Processing Record 34 of Set 5 | pareora
# Processing Record 35 of Set 5 | taoudenni
# Processing Record 36 of Set 5 | san jacinto
# Processing Record 37 of Set 5 | abilene
# Processing Record 38 of Set 5 | upernavik
# Processing Record 39 of Set 5 | manokwari
# Processing Record 40 of Set 5 | kamenskoye
# City not found, Skipping...
# Processing Record 41 of Set 5 | aleksandriya
# Processing Record 42 of Set 5 | zatyshshya
# Processing Record 43 of Set 5 | viligili
# City not found, Skipping...
# Processing Record 44 of Set 5 | marsh harbour
# Processing Record 45 of Set 5 | dakar
# Processing Record 46 of Set 5 | sumbe
# Processing Record 47 of Set 5 | quatre cocos
# Processing Record 48 of Set 5 | castro
# Processing Record 49 of Set 5 | puerto ayora
# Processing Record 50 of Set 5 | sept-iles
# Processing Record 1 of Set 6 | vestmanna
# Processing Record 2 of Set 6 | san patricio
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | excelsior springs
# Processing Record 5 of Set 6 | ancud
# Processing Record 6 of Set 6 | bengkulu
# Processing Record 7 of Set 6 | lephepe
# City not found, Skipping...
# Processing Record 8 of Set 6 | maniitsoq
# Processing Record 9 of Set 6 | moose factory
# Processing Record 10 of Set 6 | sioux lookout
# Processing Record 11 of Set 6 | nizhneyansk
# City not found, Skipping...
# Processing Record 12 of Set 6 | anloga
# Processing Record 13 of Set 6 | sarangani
# Processing Record 14 of Set 6 | lloydminster
# Processing Record 15 of Set 6 | guerrero negro
# Processing Record 16 of Set 6 | honiara
# Processing Record 17 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | burica
# City not found, Skipping...
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | aripuana
# Processing Record 22 of Set 6 | caravelas
# Processing Record 23 of Set 6 | olavarria
# Processing Record 24 of Set 6 | pemberton
# Processing Record 25 of Set 6 | cap-aux-meules
# Processing Record 26 of Set 6 | san cristobal
# Processing Record 27 of Set 6 | monterey
# Processing Record 28 of Set 6 | ponta delgada
# Processing Record 29 of Set 6 | katobu
# Processing Record 30 of Set 6 | kandla
# Processing Record 31 of Set 6 | athabasca
# Processing Record 32 of Set 6 | mahebourg
# Processing Record 33 of Set 6 | skibbereen
# Processing Record 34 of Set 6 | rio piracicaba
# Processing Record 35 of Set 6 | poum
# Processing Record 36 of Set 6 | uribia
# Processing Record 37 of Set 6 | mossendjo
# Processing Record 38 of Set 6 | los llanos de aridane
# Processing Record 39 of Set 6 | sumbawa
# City not found, Skipping...
# Processing Record 40 of Set 6 | susangerd
# Processing Record 41 of Set 6 | bunia
# Processing Record 42 of Set 6 | auburn
# Processing Record 43 of Set 6 | borba
# Processing Record 44 of Set 6 | visnes
# Processing Record 45 of Set 6 | lagoa
# Processing Record 46 of Set 6 | idlib
# Processing Record 47 of Set 6 | umm lajj
# Processing Record 48 of Set 6 | bonthe
# Processing Record 49 of Set 6 | ostrovnoy
# Processing Record 50 of Set 6 | saint george
# Processing Record 1 of Set 7 | saldanha
# Processing Record 2 of Set 7 | aykhal
# Processing Record 3 of Set 7 | saint-francois
# Processing Record 4 of Set 7 | tyssedal
# Processing Record 5 of Set 7 | labutta
# City not found, Skipping...
# Processing Record 6 of Set 7 | sabha
# Processing Record 7 of Set 7 | fairbanks
# Processing Record 8 of Set 7 | samusu
# City not found, Skipping...
# Processing Record 9 of Set 7 | belmonte
# Processing Record 10 of Set 7 | evensk
# Processing Record 11 of Set 7 | svetlogorsk
# Processing Record 12 of Set 7 | san rafael
# Processing Record 13 of Set 7 | tazovskiy
# Processing Record 14 of Set 7 | paradwip
# City not found, Skipping...
# Processing Record 15 of Set 7 | chokurdakh
# Processing Record 16 of Set 7 | millerovo
# Processing Record 17 of Set 7 | saravan
# Processing Record 18 of Set 7 | camocim
# Processing Record 19 of Set 7 | santa vitoria
# Processing Record 20 of Set 7 | nalut
# Processing Record 21 of Set 7 | bokspits
# City not found, Skipping...
# Processing Record 22 of Set 7 | xinzhi
# Processing Record 23 of Set 7 | vilhena
# Processing Record 24 of Set 7 | yarada
# Processing Record 25 of Set 7 | rio grande
# Processing Record 26 of Set 7 | zhezkazgan
# Processing Record 27 of Set 7 | lavrentiya
# Processing Record 28 of Set 7 | ruatoria
# City not found, Skipping...
# Processing Record 29 of Set 7 | hami
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | lima
# Processing Record 32 of Set 7 | terrak
# Processing Record 33 of Set 7 | vila velha
# Processing Record 34 of Set 7 | yumen
# Processing Record 35 of Set 7 | qaqortoq
# Processing Record 36 of Set 7 | caibarien
# Processing Record 37 of Set 7 | homer
# Processing Record 38 of Set 7 | santa cruz
# Processing Record 39 of Set 7 | diamantino
# Processing Record 40 of Set 7 | swellendam
# Processing Record 41 of Set 7 | guadalupe y calvo
# Processing Record 42 of Set 7 | yulara
# Processing Record 43 of Set 7 | fochville
# Processing Record 44 of Set 7 | babanusah
# City not found, Skipping...
# Processing Record 45 of Set 7 | poarta alba
# Processing Record 46 of Set 7 | nago
# Processing Record 47 of Set 7 | barabai
# Processing Record 48 of Set 7 | salamiyah
# Processing Record 49 of Set 7 | arlit
# Processing Record 50 of Set 7 | medianeira
# Processing Record 1 of Set 8 | innisfail
# Processing Record 2 of Set 8 | santiago del estero
# Processing Record 3 of Set 8 | launceston
# Processing Record 4 of Set 8 | mosalsk
# Processing Record 5 of Set 8 | makakilo city
# Processing Record 6 of Set 8 | harper
# Processing Record 7 of Set 8 | ormara
# Processing Record 8 of Set 8 | chaadayevka
# Processing Record 9 of Set 8 | porbandar
# Processing Record 10 of Set 8 | norrtalje
# Processing Record 11 of Set 8 | mingguang
# Processing Record 12 of Set 8 | prince rupert
# Processing Record 13 of Set 8 | inuvik
# Processing Record 14 of Set 8 | victor harbor
# Processing Record 15 of Set 8 | pangnirtung
# Processing Record 16 of Set 8 | nata
# Processing Record 17 of Set 8 | cap malheureux
# Processing Record 18 of Set 8 | robstown
# Processing Record 19 of Set 8 | faanui
# Processing Record 20 of Set 8 | samarai
# Processing Record 21 of Set 8 | maneadero
# Processing Record 22 of Set 8 | atbasar
# Processing Record 23 of Set 8 | mondlo
# Processing Record 24 of Set 8 | shenjiamen
# Processing Record 25 of Set 8 | la seyne-sur-mer
# Processing Record 26 of Set 8 | antropovo
# Processing Record 27 of Set 8 | jalu
# Processing Record 28 of Set 8 | plouzane
# Processing Record 29 of Set 8 | ilulissat
# Processing Record 30 of Set 8 | mehran
# Processing Record 31 of Set 8 | boyolangu
# Processing Record 32 of Set 8 | moyale
# Processing Record 33 of Set 8 | touros
# Processing Record 34 of Set 8 | cabo san lucas
# Processing Record 35 of Set 8 | talnakh
# Processing Record 36 of Set 8 | rocha
# Processing Record 37 of Set 8 | guarapari
# Processing Record 38 of Set 8 | taolanaro
# City not found, Skipping...
# Processing Record 39 of Set 8 | bud
# Processing Record 40 of Set 8 | lagos
# Processing Record 41 of Set 8 | kaeo
# Processing Record 42 of Set 8 | hukuntsi
# Processing Record 43 of Set 8 | roding
# Processing Record 44 of Set 8 | katherine
# Processing Record 45 of Set 8 | nebbi
# Processing Record 46 of Set 8 | karasjok
# Processing Record 47 of Set 8 | faya
# Processing Record 48 of Set 8 | hammerfest
# Processing Record 49 of Set 8 | sebinkarahisar
# Processing Record 50 of Set 8 | longjiang
# Processing Record 1 of Set 9 | bilma
# Processing Record 2 of Set 9 | flin flon
# Processing Record 3 of Set 9 | dolores
# Processing Record 4 of Set 9 | puro
# Processing Record 5 of Set 9 | tampere
# Processing Record 6 of Set 9 | vanimo
# Processing Record 7 of Set 9 | bandarbeyla
# Processing Record 8 of Set 9 | floro
# Processing Record 9 of Set 9 | shahreza
# Processing Record 10 of Set 9 | nelson bay
# Processing Record 11 of Set 9 | soure
# Processing Record 12 of Set 9 | ilebo
# Processing Record 13 of Set 9 | sitka
# Processing Record 14 of Set 9 | mathbaria
# Processing Record 15 of Set 9 | nhulunbuy
# Processing Record 16 of Set 9 | oyama
# Processing Record 17 of Set 9 | berlevag
# Processing Record 18 of Set 9 | nioro
# Processing Record 19 of Set 9 | george
# Processing Record 20 of Set 9 | chuguyevka
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | naryan-mar
# Processing Record 23 of Set 9 | grants
# Processing Record 24 of Set 9 | sierra vista
# Processing Record 25 of Set 9 | comodoro rivadavia
# Processing Record 26 of Set 9 | dzhusaly
# City not found, Skipping...
# Processing Record 27 of Set 9 | matamoros
# Processing Record 28 of Set 9 | north marysville
# City not found, Skipping...
# Processing Record 29 of Set 9 | novoagansk
# Processing Record 30 of Set 9 | sitia
# Processing Record 31 of Set 9 | yanan
# City not found, Skipping...
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | vardo
# Processing Record 34 of Set 9 | seydi
# Processing Record 35 of Set 9 | broome
# Processing Record 36 of Set 9 | anzhero-sudzhensk
# Processing Record 37 of Set 9 | say
# Processing Record 38 of Set 9 | oskemen
# Processing Record 39 of Set 9 | emet
# Processing Record 40 of Set 9 | ibipora
# Processing Record 41 of Set 9 | jarvenpaa
# Processing Record 42 of Set 9 | salalah
# Processing Record 43 of Set 9 | kishtwar
# Processing Record 44 of Set 9 | vila franca do campo
# Processing Record 45 of Set 9 | westport
# Processing Record 46 of Set 9 | strelca
# City not found, Skipping...
# Processing Record 47 of Set 9 | camana
# Processing Record 48 of Set 9 | bathsheba
# Processing Record 49 of Set 9 | khani
# Processing Record 50 of Set 9 | wasilla
# Processing Record 1 of Set 10 | dunmore
# Processing Record 2 of Set 10 | valdivia
# Processing Record 3 of Set 10 | marystown
# Processing Record 4 of Set 10 | marzuq
# Processing Record 5 of Set 10 | naftah
# City not found, Skipping...
# Processing Record 6 of Set 10 | santo domingo suchitepequez
# Processing Record 7 of Set 10 | sao joao da barra
# Processing Record 8 of Set 10 | puerto carreno
# Processing Record 9 of Set 10 | kitzbuhel
# Processing Record 10 of Set 10 | masyaf
# Processing Record 11 of Set 10 | walvis bay
# Processing Record 12 of Set 10 | dalvik
# Processing Record 13 of Set 10 | atar
# Processing Record 14 of Set 10 | hithadhoo
# Processing Record 15 of Set 10 | zyryanka
# Processing Record 16 of Set 10 | kaitangata
# Processing Record 17 of Set 10 | dauphin
# Processing Record 18 of Set 10 | kihei
# Processing Record 19 of Set 10 | college
# Processing Record 20 of Set 10 | lompoc
# Processing Record 21 of Set 10 | garowe
# Processing Record 22 of Set 10 | saint-alexandre
# Processing Record 23 of Set 10 | fort saint john
# City not found, Skipping...
# Processing Record 24 of Set 10 | tsihombe
# City not found, Skipping...
# Processing Record 25 of Set 10 | muriti
# Processing Record 26 of Set 10 | grand river south east
# City not found, Skipping...
# Processing Record 27 of Set 10 | vammala
# Processing Record 28 of Set 10 | janakpur
# Processing Record 29 of Set 10 | jaisalmer
# Processing Record 30 of Set 10 | alfredo chaves
# Processing Record 31 of Set 10 | changli
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | staryy nadym
# Processing Record 34 of Set 10 | arkhangelsk
# Processing Record 35 of Set 10 | fort nelson
# Processing Record 36 of Set 10 | roebourne
# Processing Record 37 of Set 10 | pilar
# Processing Record 38 of Set 10 | baracoa
# Processing Record 39 of Set 10 | nalgonda
# Processing Record 40 of Set 10 | palu
# Processing Record 41 of Set 10 | kande
# Processing Record 42 of Set 10 | sur
# Processing Record 43 of Set 10 | maebaru
# Processing Record 44 of Set 10 | arica
# Processing Record 45 of Set 10 | san mateo
# Processing Record 46 of Set 10 | kahului
# Processing Record 47 of Set 10 | gat
# Processing Record 48 of Set 10 | shushtar
# Processing Record 49 of Set 10 | kruisfontein
# Processing Record 50 of Set 10 | berdyuzhye
# City not found, Skipping...
# Processing Record 1 of Set 11 | solwezi
# Processing Record 2 of Set 11 | marsa matruh
# Processing Record 3 of Set 11 | tahoua
# Processing Record 4 of Set 11 | kuvandyk
# Processing Record 5 of Set 11 | sembe
# Processing Record 6 of Set 11 | chaman
# Processing Record 7 of Set 11 | lata
# Processing Record 8 of Set 11 | semey
# Processing Record 9 of Set 11 | goundam
# Processing Record 10 of Set 11 | tumannyy
# City not found, Skipping...
# Processing Record 11 of Set 11 | vestmannaeyjar
# Processing Record 12 of Set 11 | asuncion
# Processing Record 13 of Set 11 | manggar
# Processing Record 14 of Set 11 | provideniya
# Processing Record 15 of Set 11 | kontagora
# Processing Record 16 of Set 11 | prince george
# Processing Record 17 of Set 11 | dongsheng
# Processing Record 18 of Set 11 | hailar
# Processing Record 19 of Set 11 | louisbourg
# City not found, Skipping...
# Processing Record 20 of Set 11 | maxixe
# Processing Record 21 of Set 11 | price
# Processing Record 22 of Set 11 | sobolevo
# Processing Record 23 of Set 11 | trincomalee
# Processing Record 24 of Set 11 | teresina
# Processing Record 25 of Set 11 | stanger
# Processing Record 26 of Set 11 | tuatapere
# Processing Record 27 of Set 11 | euclides da cunha
# Processing Record 28 of Set 11 | darnah
# Processing Record 29 of Set 11 | kurkino
# Processing Record 30 of Set 11 | batemans bay
# Processing Record 31 of Set 11 | caldas novas
# Processing Record 32 of Set 11 | mitsamiouli
# Processing Record 33 of Set 11 | tumbagaan
# Processing Record 34 of Set 11 | phan rang
# City not found, Skipping...
# Processing Record 35 of Set 11 | hambantota
# Processing Record 36 of Set 11 | constitucion
# Processing Record 37 of Set 11 | gao
# Processing Record 38 of Set 11 | kirakira
# Processing Record 39 of Set 11 | smithers
# Processing Record 40 of Set 11 | semirom
# Processing Record 41 of Set 11 | camacha
# Processing Record 42 of Set 11 | arefu
# Processing Record 43 of Set 11 | henties bay
# Processing Record 44 of Set 11 | codrington
# Processing Record 45 of Set 11 | buariki
# City not found, Skipping...
# Processing Record 46 of Set 11 | daura
# Processing Record 47 of Set 11 | fayetteville
# Processing Record 48 of Set 11 | kantilo
# Processing Record 49 of Set 11 | marshall
# Processing Record 50 of Set 11 | khuzhir
# Processing Record 1 of Set 12 | kralendijk
# Processing Record 2 of Set 12 | gari
# Processing Record 3 of Set 12 | itaituba
# Processing Record 4 of Set 12 | hermosillo
# Processing Record 5 of Set 12 | kutno
# Processing Record 6 of Set 12 | ibra
# Processing Record 7 of Set 12 | riyadh
# Processing Record 8 of Set 12 | veraval
# Processing Record 9 of Set 12 | yinchuan
# Processing Record 10 of Set 12 | jacupiranga
# Processing Record 11 of Set 12 | sasykoli
# Processing Record 12 of Set 12 | dicabisagan
# Processing Record 13 of Set 12 | okhotsk
# Processing Record 14 of Set 12 | matara
# Processing Record 15 of Set 12 | macau
# Processing Record 16 of Set 12 | yuncheng
# Processing Record 17 of Set 12 | sao raimundo das mangabeiras
# Processing Record 18 of Set 12 | melekhovskaya
# City not found, Skipping...
# Processing Record 19 of Set 12 | xingyi
# Processing Record 20 of Set 12 | omboue
# Processing Record 21 of Set 12 | lexington
# Processing Record 22 of Set 12 | tiarei
# Processing Record 23 of Set 12 | yaan
# Processing Record 24 of Set 12 | mackay
# Processing Record 25 of Set 12 | pauini
# Processing Record 26 of Set 12 | grand centre
# City not found, Skipping...
# Processing Record 27 of Set 12 | la ronge
# Processing Record 28 of Set 12 | haines junction
# Processing Record 29 of Set 12 | lucapa
# Processing Record 30 of Set 12 | ballangen
# Processing Record 31 of Set 12 | la palma
# Processing Record 32 of Set 12 | scarborough
# Processing Record 33 of Set 12 | aanekoski
# Processing Record 34 of Set 12 | erenhot
# Processing Record 35 of Set 12 | carballo
# Processing Record 36 of Set 12 | maumere
# Processing Record 37 of Set 12 | tambun
# Processing Record 38 of Set 12 | kovur
# Processing Record 39 of Set 12 | channel-port aux basques
# Processing Record 40 of Set 12 | necochea
# Processing Record 41 of Set 12 | burns lake
# Processing Record 42 of Set 12 | broken hill
# Processing Record 43 of Set 12 | baisha
# Processing Record 44 of Set 12 | abha
# Processing Record 45 of Set 12 | teknaf
# Processing Record 46 of Set 12 | charters towers
# Processing Record 47 of Set 12 | alice springs
# Processing Record 48 of Set 12 | rundu
# Processing Record 49 of Set 12 | mount isa
# Processing Record 50 of Set 12 | ambodifototra
# City not found, Skipping...
# Processing Record 1 of Set 13 | vuktyl
# Processing Record 2 of Set 13 | biak
# Processing Record 3 of Set 13 | kalabo
# Processing Record 4 of Set 13 | yaring
# Processing Record 5 of Set 13 | soyo
# Processing Record 6 of Set 13 | bichura
# Processing Record 7 of Set 13 | manado
# Processing Record 8 of Set 13 | khovu-aksy
# Processing Record 9 of Set 13 | hai phong
# City not found, Skipping...
# Processing Record 10 of Set 13 | kochki
# Processing Record 11 of Set 13 | terrace bay
# Processing Record 12 of Set 13 | kayes
# Processing Record 13 of Set 13 | labuhan
# Processing Record 14 of Set 13 | mahajanga
# Processing Record 15 of Set 13 | araouane
# Processing Record 16 of Set 13 | alamosa
# Processing Record 17 of Set 13 | nastola
# Processing Record 18 of Set 13 | tuyen quang
# Processing Record 19 of Set 13 | namibe
# Processing Record 20 of Set 13 | concepcion del oro
# Processing Record 21 of Set 13 | lebedinyy
# Processing Record 22 of Set 13 | gunjur
# Processing Record 23 of Set 13 | oswego
# Processing Record 24 of Set 13 | tura
# Processing Record 25 of Set 13 | jutai
# Processing Record 26 of Set 13 | chiredzi
# Processing Record 27 of Set 13 | morehead
# Processing Record 28 of Set 13 | yerbogachen
# Processing Record 29 of Set 13 | half moon bay
# Processing Record 30 of Set 13 | vernon
# Processing Record 31 of Set 13 | kurchum
# Processing Record 32 of Set 13 | dromolaxia
# Processing Record 33 of Set 13 | vavuniya
# Processing Record 34 of Set 13 | chibombo
# Processing Record 35 of Set 13 | kloulklubed
# Processing Record 36 of Set 13 | dahod
# Processing Record 37 of Set 13 | marrakesh
# Processing Record 38 of Set 13 | ketchikan
# Processing Record 39 of Set 13 | villa florida
# Processing Record 40 of Set 13 | kimbe
# Processing Record 41 of Set 13 | bossier city
# Processing Record 42 of Set 13 | sahrak
# City not found, Skipping...
# Processing Record 43 of Set 13 | buin
# Processing Record 44 of Set 13 | arman
# Processing Record 45 of Set 13 | lasa
# Processing Record 46 of Set 13 | pinega
# Processing Record 47 of Set 13 | mys shmidta
# City not found, Skipping...
# Processing Record 48 of Set 13 | edd
# Processing Record 49 of Set 13 | aquiraz
# Processing Record 50 of Set 13 | tabou
# Processing Record 1 of Set 14 | yarmouth
# Processing Record 2 of Set 14 | cravo norte
# Processing Record 3 of Set 14 | poltavka
# Processing Record 4 of Set 14 | port keats
# Processing Record 5 of Set 14 | alofi
# Processing Record 6 of Set 14 | big spring
# Processing Record 7 of Set 14 | khor
# Processing Record 8 of Set 14 | kuytun
# Processing Record 9 of Set 14 | puerto madero
# Processing Record 10 of Set 14 | mbanza-ngungu
# Processing Record 11 of Set 14 | jiwani
# Processing Record 12 of Set 14 | carmelo
# Processing Record 13 of Set 14 | camacupa
# Processing Record 14 of Set 14 | natal
# Processing Record 15 of Set 14 | kapit
# Processing Record 16 of Set 14 | novyy yarychiv
# Processing Record 17 of Set 14 | flinders
# Processing Record 18 of Set 14 | chifeng
# Processing Record 19 of Set 14 | kirkenaer
# Processing Record 20 of Set 14 | robertsport
# Processing Record 21 of Set 14 | uruzgan
# Processing Record 22 of Set 14 | aras
# Processing Record 23 of Set 14 | hofn
# Processing Record 24 of Set 14 | camabatela
# Processing Record 25 of Set 14 | angoram
# Processing Record 26 of Set 14 | panlaitan
# Processing Record 27 of Set 14 | dali
# Processing Record 28 of Set 14 | touba
# Processing Record 29 of Set 14 | dorogobuzh
# Processing Record 30 of Set 14 | merauke
# Processing Record 31 of Set 14 | pokhara
# Processing Record 32 of Set 14 | tromso
# Processing Record 33 of Set 14 | damavand
# Processing Record 34 of Set 14 | harnosand
# Processing Record 35 of Set 14 | bilibino
# Processing Record 36 of Set 14 | vila
# Processing Record 37 of Set 14 | acarau
# Processing Record 38 of Set 14 | ashta
# Processing Record 39 of Set 14 | sulejowek
# Processing Record 40 of Set 14 | dogondoutchi
# Processing Record 41 of Set 14 | talaya
# Processing Record 42 of Set 14 | teyateyaneng
# Processing Record 43 of Set 14 | salinopolis
# Processing Record 44 of Set 14 | bolungarvik
# City not found, Skipping...
# Processing Record 45 of Set 14 | koslan
# Processing Record 46 of Set 14 | ambilobe
# Processing Record 47 of Set 14 | iqaluit
# Processing Record 48 of Set 14 | ola
# Processing Record 49 of Set 14 | pacific grove
# Processing Record 50 of Set 14 | dangara
# Processing Record 1 of Set 15 | cozumel
# Processing Record 2 of Set 15 | adrar
# Processing Record 3 of Set 15 | mandalgovi
# Processing Record 4 of Set 15 | san carlos de bariloche
# Processing Record 5 of Set 15 | antequera
# Processing Record 6 of Set 15 | shouguang
# Processing Record 7 of Set 15 | voloshka
# Processing Record 8 of Set 15 | zhengjiatun
# Processing Record 9 of Set 15 | blonduos
# City not found, Skipping...
# Processing Record 10 of Set 15 | juodupe
# Processing Record 11 of Set 15 | lokosovo
# Processing Record 12 of Set 15 | urengoy
# Processing Record 13 of Set 15 | linqiong
# Processing Record 14 of Set 15 | bassano
# Processing Record 15 of Set 15 | la orilla
# Processing Record 16 of Set 15 | hvide sande
# Processing Record 17 of Set 15 | ust-kuyga
# Processing Record 18 of Set 15 | sheltozero
# Processing Record 19 of Set 15 | saint-joseph
# Processing Record 20 of Set 15 | methoni
# Processing Record 21 of Set 15 | isabela
# Processing Record 22 of Set 15 | champerico
# Processing Record 23 of Set 15 | terney
# Processing Record 24 of Set 15 | guaira
# Processing Record 25 of Set 15 | agua buena
# Processing Record 26 of Set 15 | ip
# City not found, Skipping...
# Processing Record 27 of Set 15 | betioky
# Processing Record 28 of Set 15 | gerash
# Processing Record 29 of Set 15 | coahuayana
# Processing Record 30 of Set 15 | makaha
# Processing Record 31 of Set 15 | kupang
# Processing Record 32 of Set 15 | christchurch
# Processing Record 33 of Set 15 | mehamn
# Processing Record 34 of Set 15 | mmabatho
# Processing Record 35 of Set 15 | sao paulo de olivenca
# Processing Record 36 of Set 15 | ambunti
# Processing Record 37 of Set 15 | makarov
# Processing Record 38 of Set 15 | ozgon
# City not found, Skipping...
# Processing Record 39 of Set 15 | porto novo
# Processing Record 40 of Set 15 | shar
# Processing Record 41 of Set 15 | paita
# Processing Record 42 of Set 15 | candido mendes
# Processing Record 43 of Set 15 | melville
# Processing Record 44 of Set 15 | tutoia
# Processing Record 45 of Set 15 | shima
# Processing Record 46 of Set 15 | kitakami
# Processing Record 47 of Set 15 | crab hill
# City not found, Skipping...
# Processing Record 48 of Set 15 | aflu
# City not found, Skipping...
# Processing Record 49 of Set 15 | kailahun
# Processing Record 50 of Set 15 | grand falls
# Processing Record 1 of Set 16 | roald
# Processing Record 2 of Set 16 | margate
# Processing Record 3 of Set 16 | ileza
# Processing Record 4 of Set 16 | novo aripuana
# Processing Record 5 of Set 16 | dunedin
# Processing Record 6 of Set 16 | eskilstuna
# Processing Record 7 of Set 16 | nacala
# Processing Record 8 of Set 16 | namie
# Processing Record 9 of Set 16 | booue
# Processing Record 10 of Set 16 | dudinka
# Processing Record 11 of Set 16 | richards bay
# Processing Record 12 of Set 16 | talara
# Processing Record 13 of Set 16 | gayeri
# Processing Record 14 of Set 16 | taguatinga
# Processing Record 15 of Set 16 | durban
# Processing Record 16 of Set 16 | soria
# Processing Record 17 of Set 16 | anadyr
# Processing Record 18 of Set 16 | havre-saint-pierre
# Processing Record 19 of Set 16 | wawa
# Processing Record 20 of Set 16 | naugarzan
# City not found, Skipping...
# Processing Record 21 of Set 16 | mantua
# Processing Record 22 of Set 16 | spearfish
# Processing Record 23 of Set 16 | barcelos
# Processing Record 24 of Set 16 | umzimvubu
# City not found, Skipping...
# Processing Record 25 of Set 16 | san javier
# Processing Record 26 of Set 16 | yar-sale
# Processing Record 27 of Set 16 | boa vista
# Processing Record 28 of Set 16 | bargal
# City not found, Skipping...
# Processing Record 29 of Set 16 | otane
# Processing Record 30 of Set 16 | leningradskiy
# Processing Record 31 of Set 16 | kuloy
# Processing Record 32 of Set 16 | pincher creek
# Processing Record 33 of Set 16 | emilio carranza
# Processing Record 34 of Set 16 | batagay-alyta
# Processing Record 35 of Set 16 | kuryk
# Processing Record 36 of Set 16 | nicolas bravo
# Processing Record 37 of Set 16 | khorol
# Processing Record 38 of Set 16 | zhangjiakou
# Processing Record 39 of Set 16 | valleyview
# Processing Record 40 of Set 16 | barda
# Processing Record 41 of Set 16 | belousovka
# Processing Record 42 of Set 16 | oksfjord
# Processing Record 43 of Set 16 | jatai
# Processing Record 44 of Set 16 | leshukonskoye
# Processing Record 45 of Set 16 | la grande
# Processing Record 46 of Set 16 | tabiauea
# City not found, Skipping...
# Processing Record 47 of Set 16 | zelenets
# Processing Record 48 of Set 16 | saint-gaudens
# Processing Record 49 of Set 16 | dien bien
# City not found, Skipping...
# Processing Record 50 of Set 16 | santa vitoria do palmar
# Processing Record 1 of Set 17 | orlik
# Processing Record 2 of Set 17 | bon accord
# ----------------------------
# Date Retrieval Complete
# ----------------------------

# %%
len(city_data)
# Out:
# 744

# %%
#Convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Butaritari      KI   3.0707  172.7902     27.32        76          80
# 1       Chumikan      RU  54.7183  135.3150    -23.69        93          98
# 2          Kapaa      US  22.0752 -159.3190     25.18        84          75
# 3       Hermanus      ZA -34.4187   19.2345     18.28        73          85
# 4          Vaini      TO -21.2000 -175.2000     25.09        83          75
# 5          Airai      TL  -8.9266  125.4092     16.59        88          98
# 6        Ushuaia      AR -54.8000  -68.3000     11.81        47          40
# 7  Srednekolymsk      RU  67.4500  153.6833    -33.20       100          96
# 8      Grindavik      IS  63.8424  -22.4338     -1.74        74          90
# 9         Albany      US  42.6001  -73.9662      5.81        69          99
#
#    Wind Speed Current Description
# 0        4.25       broken clouds
# 1        4.80     overcast clouds
# 2        5.66          light rain
# 3        5.99     overcast clouds
# 4        3.60       broken clouds
# 5        0.52     overcast clouds
# 6        6.17    scattered clouds
# 7        2.95     overcast clouds
# 8        3.60     overcast clouds
# 9        0.45     overcast clouds

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export the city_data into CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
